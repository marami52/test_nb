# %% [markdown]
# ** This notebook has lots of dependencies. You can clone this notebook by visiting: [R-Brain html widgets notebook](https://app.r-brain.io/#/share/notebook/aaf5a97ec0ef44b98bf4fdd5e463a859/0510e165f4794ef19d95855a76ffc9d9) **

# %% [markdown]
# # DataTable view

# %%
library(DT)
datatable(mtcars)
# Out:
# <script>
#     /*
#      * File: iframeResizer.js
#      * Desc: Force iframes to size to content.
#      * Requires: iframeResizer.contentWindow.js to be loaded into the target frame.
#      * Doc: https://github.com/davidjbradshaw/iframe-resizer
#      * Author: David J. Bradshaw - dave@bradshaw.net
#      * Contributor: Jure Mav - jure.mav@gmail.com
#      * Contributor: Reed Dadoune - reed@dadoune.com
#      */
#
#     if (typeof iFrameResize === 'undefined') {
#     ;(function(window) {
#         'use strict';
#
#         var
#             count                 = 0,
#             logEnabled            = false,
#             hiddenCheckEnabled    = false,
#             msgHeader             = 'message',
#             msgHeaderLen          = msgHeader.length,
#             msgId                 = '[iFrameSizer]', //Must match iframe msg ID
#             msgIdLen              = msgId.length,
#             pagePosition          = null,
# ...

# %% [markdown]
# # Heat map

# %%
library(d3heatmap)
d3heatmap(mtcars, scale = "column", colors = "Spectral")
# Out:
# <iframe height="400px" width="100%" scrolling="auto" seamless="seamless" style="resize:vertical;" frameborder="0" srcDoc="<!DOCTYPE html>
# <html>
# <head>
# <meta charset=&quot;utf-8&quot;/>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb37256db7a/lib/htmlwidgets-0.8/htmlwidgets.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb37256db7a/lib/d3-3.5.3/./d3.min.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb37256db7a/lib/d3heatmapcore-0.0.0/heatmapcore.css --><link href=&quot;data:text/css;base64,...&quot; rel=&quot;stylesheet&quot; />
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb37256db7a/lib/d3heatmapcore-0.0.0/heatmapcore.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb37256db7a/lib/d3-tip-0.6.6/index.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# ...

# %% [markdown]
# # Network D3 - simple network

# %%
library(networkD3)

# Create sample data
src <- c("A", "A", "A", "A",
        "B", "B", "C", "C", "D")
target <- c("B", "C", "D", "J",
            "E", "F", "G", "H", "I")
networkData <- data.frame(src, target)

# Plot
simpleNetwork(networkData)
# Out:
# Attaching package: ‘networkD3’
#
# The following object is masked from ‘package:DT’:
#
#     JS
# <iframe height="400px" width="100%" scrolling="auto" seamless="seamless" style="resize:vertical;" frameborder="0" srcDoc="<!DOCTYPE html>
# <html>
# <head>
# <meta charset=&quot;utf-8&quot;/>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb35ae78271/lib/htmlwidgets-0.8/htmlwidgets.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb35ae78271/lib/d3-3.5.2/d3.min.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb35ae78271/lib/simpleNetwork-binding-0.2.13/simpleNetwork.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
#
# </head>
# <body style=&quot;background-color:white;&quot;>
# <div id=&quot;htmlwidget_container&quot;>
# ...

# %% [markdown]
# # Network D3 - Force Netwrok

# %%
# Load data
data(MisLinks)
data(MisNodes)

# Plot
forceNetwork(Links = MisLinks, Nodes = MisNodes,
            Source = "source", Target = "target",
            Value = "value", NodeID = "name",
            Group = "group", opacity = 0.8)
# Out:
# <iframe height="400px" width="100%" scrolling="auto" seamless="seamless" style="resize:vertical;" frameborder="0" srcDoc="<!DOCTYPE html>
# <html>
# <head>
# <meta charset=&quot;utf-8&quot;/>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb36283367/lib/htmlwidgets-0.8/htmlwidgets.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb36283367/lib/d3-3.5.2/d3.min.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb36283367/lib/forceNetwork-binding-0.2.13/forceNetwork.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
#
# </head>
# <body style=&quot;background-color:white;&quot;>
# <div id=&quot;htmlwidget_container&quot;>
#   <div id=&quot;htmlwidget-44a5b300b65e59a124eb&quot; style=&quot;width:960px;height:500px;&quot; class=&quot;forceNetwork html-widget&quot;></div>
# </div>
# ...

# %% [markdown]
# # Network - Sankey Network

# %%
URL <- paste0(
        "https://cdn.rawgit.com/christophergandrud/networkD3/",
        "master/JSONdata/energy.json")
Energy <- jsonlite::fromJSON(URL)


# Plot
sankeyNetwork(Links = Energy$links, Nodes = Energy$nodes, Source = "source",
             Target = "target", Value = "value", NodeID = "name",
             units = "TWh", fontSize = 12, nodeWidth = 30)


URL <- paste0(
        "https://cdn.rawgit.com/christophergandrud/networkD3/",
        "master/JSONdata//flare.json")

## Convert to list format
Flare <- jsonlite::fromJSON(URL, simplifyDataFrame = FALSE)

# Use subset of data for more readable diagram
Flare$children = Flare$children[1:3]

radialNetwork(List = Flare, fontSize = 10, opacity = 0.9)
# Out:
# <iframe height="400px" width="100%" scrolling="auto" seamless="seamless" style="resize:vertical;" frameborder="0" srcDoc="<!DOCTYPE html>
# <html>
# <head>
# <meta charset=&quot;utf-8&quot;/>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb342ca777e/lib/htmlwidgets-0.8/htmlwidgets.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb342ca777e/lib/d3-3.5.2/d3.min.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb342ca777e/lib/sankey-1/sankey.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb342ca777e/lib/sankeyNetwork-binding-0.2.13/sankeyNetwork.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
#
# </head>
# <body style=&quot;background-color:white;&quot;>
# <div id=&quot;htmlwidget_container&quot;>
# ...

# %% [markdown]
# # Open Maps

# %%
library(leaflet)
m <- leaflet()
m <- addTiles(m)
m <- addMarkers(m, lng=174.768, lat=-36.852, popup="The birthplace of R")
m
# Out:
# Attaching package: ‘leaflet’
#
# The following object is masked from ‘package:networkD3’:
#
#     JS
# <iframe height="400px" width="100%" scrolling="auto" seamless="seamless" style="resize:vertical;" frameborder="0" srcDoc="<!DOCTYPE html>
# <html>
# <head>
# <meta charset=&quot;utf-8&quot;/>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb336acd6/lib/htmlwidgets-0.8/htmlwidgets.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb336acd6/lib/jquery-1.11.1/jquery.min.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb336acd6/lib/leaflet-0.7.3/leaflet.css --><link href=&quot;data:text/css;base64,...&quot; rel=&quot;stylesheet&quot; />
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb336acd6/lib/leaflet-0.7.3/leaflet.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# ...

# %% [markdown]
# # 3D Graph

# %%
library(threejs)

# Plot flights to frequent destinations from
# Callum Prentice's global flight data set,
# http://callumprentice.github.io/apps/flight_stream/index.html
data(flights)

# Approximate locations as factors
dest   <- factor(sprintf("%.2f:%.2f",flights[,3], flights[,4]))

# A table of destination frequencies
freq <- sort(table(dest), decreasing=TRUE)

# The most frequent destinations in these data, possibly hub airports?
frequent_destinations <- names(freq)[1:10]

# Subset the flight data by destination frequency
idx <- dest %in% frequent_destinations
frequent_flights <- flights[idx, ]

# Lat/long of frequent destinations
latlong <- unique(frequent_flights[,3:4])

# Plot frequent destinations as bars, and the flights to and from
# them as arcs. Adjust arc width and color by frequency.
earth <- system.file("images/world.jpg",  package="threejs")
globejs(img=earth, lat=latlong[,1], long=latlong[,2], arcs=frequent_flights,
        arcsHeight=0.3, arcsLwd=2, arcsColor="#ffff00", arcsOpacity=0.15,
        atmosphere=TRUE)
# Out:
# <iframe height="400px" width="100%" scrolling="auto" seamless="seamless" style="resize:vertical;" frameborder="0" srcDoc="<!DOCTYPE html>
# <html>
# <head>
# <meta charset=&quot;utf-8&quot;/>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb3738196e6/lib/htmlwidgets-0.8/htmlwidgets.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb3738196e6/lib/threejs-70/three.min.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb3738196e6/lib/threejs-70/Detector.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb3738196e6/lib/threejs-70/Projector.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb3738196e6/lib/threejs-70/CanvasRenderer.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# ...

# %% [markdown]
# # Another example of 3D graph

# %%
N <- 100
i <- sample(3, N, replace=TRUE)
x <- matrix(rnorm(N*3),ncol=3)
lab <- c("small", "bigger", "biggest")
scatterplot3js(x, color=rainbow(N), labels=lab[i], size=i, renderer="canvas")
# Out:
# <iframe height="400px" width="100%" scrolling="auto" seamless="seamless" style="resize:vertical;" frameborder="0" srcDoc="<!DOCTYPE html>
# <html>
# <head>
# <meta charset=&quot;utf-8&quot;/>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb3797eb1b1/lib/htmlwidgets-0.8/htmlwidgets.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb3797eb1b1/lib/threejs-70/three.min.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb3797eb1b1/lib/threejs-70/Detector.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb3797eb1b1/lib/threejs-70/Projector.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# <!-- inlined /tmp/RtmpbnD1Hd/viewhtmlb3797eb1b1/lib/threejs-70/CanvasRenderer.js --><script src=&quot;data:text/javascript;base64,...&quot;></script>
# ...

# %%
df <- as.data.frame(mtcars)
